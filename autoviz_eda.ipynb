# %%
from autoviz.AutoViz_Class import AutoViz_Class
import pandas as pd
AV = AutoViz_Class()

filename = "data.csv"
df = pd.read_csv(filename)
label_mapping = {'Yes': 1, 'No': 0}

# 'Label'列をマップして変換
purpose = "Attrition"

df[purpose] = df[purpose].map(label_mapping)
# depVarに目的変数、dfteにEDAしたいデータをセットする
dft = AV.AutoViz( "" ,sep=',', depVar=purpose, dfte=df, header=0, verbose=2,
lowess=False,chart_format='svg',max_rows_analyzed=1500,max_cols_analyzed=30)
# Out:
# Imported v0.1.804. After importing autoviz, you must run '%matplotlib inline' to display charts inline.
#     AV = AutoViz_Class()
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (1470, 38)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing upto 30 columns (max) in each category:
#     Numeric Columns : []
#     Integer-Categorical Columns: ['Age', 'DailyAchievement', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyAchievement', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyAchievement', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Incentive', 'RemoteWork']
#     String-Categorical Columns: ['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus', 'HowToEmploy']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['Gender', 'OverTime']
#     Numeric-Boolean Columns: []
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: ['EmployeeNumber']
#     Columns that will not be considered in modeling: ['EmployeeCount', 'Over18', 'StandardHours']
#     37 Predictors classified...
#         4 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['EmployeeNumber', 'EmployeeCount', 'Over18', 'StandardHours']
#
# ################ Binary_Classification problem #####################
# Number of variables = 33 exceeds limit, finding top 30 variables through XGBoost
#     No categorical feature reduction done. All 8 Categorical vars selected
#     Removing correlated variables from 25 numerics using SULO method
#
# After removing highly correlated variables, following 20 numeric vars selected: ['Age', 'DailyAchievement', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyAchievement', 'JobInvolvement', 'JobSatisfaction', 'MonthlyAchievement', 'NumCompaniesWorked', 'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsSinceLastPromotion', 'Incentive', 'RemoteWork', 'JobLevel', 'YearsInCurrentRole', 'PercentSalaryHike']
#     Adding 8 categorical variables to reduced numeric variables  of 20
# ############## F E A T U R E   S E L E C T I O N  ####################
# Current number of predictors = 28
#     Finding Important Features using Boosted Trees algorithm...
#         using 28 variables...
# Finding top features using XGB is crashing. Continuing with all predictors...
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     28 Predictors classified...
#     No variables removed since no ID or low-information variables found in data
#     List of variables removed: []
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_cd4f6_row0_col0, #T_cd4f6_row0_col3, #T_cd4f6_row0_col4, #T_cd4f6_row0_col5, #T_cd4f6_row1_col0, #T_cd4f6_row1_col3, #T_cd4f6_row1_col4, #T_cd4f6_row1_col5, #T_cd4f6_row2_col0, #T_cd4f6_row2_col3, #T_cd4f6_row2_col4, #T_cd4f6_row2_col5, #T_cd4f6_row3_col0, #T_cd4f6_row3_col3, #T_cd4f6_row3_col4, #T_cd4f6_row3_col5, #T_cd4f6_row4_col0, #T_cd4f6_row4_col3, #T_cd4f6_row4_col4, #T_cd4f6_row4_col5, #T_cd4f6_row5_col0, #T_cd4f6_row5_col3, #T_cd4f6_row5_col4, #T_cd4f6_row5_col5, #T_cd4f6_row6_col0, #T_cd4f6_row6_col3, #T_cd4f6_row6_col4, #T_cd4f6_row6_col5, #T_cd4f6_row7_col0, #T_cd4f6_row7_col3, #T_cd4f6_row7_col4, #T_cd4f6_row7_col5, #T_cd4f6_row8_col0, #T_cd4f6_row8_col3, #T_cd4f6_row8_col4, #T_cd4f6_row8_col5, #T_cd4f6_row9_col0, #T_cd4f6_row9_col3, #T_cd4f6_row9_col4, #T_cd4f6_row9_col5, #T_cd4f6_row10_col0, #T_cd4f6_row10_col3, #T_cd4f6_row10_col4, #T_cd4f6_row10_col5, #T_cd4f6_row11_col0, #T_cd4f6_row11_col3, #T_cd4f6_row11_col4, #T_cd4f6_row11_col5, #T_cd4f6_row12_col0, #T_cd4f6_row12_col3, #T_cd4f6_row12_col4, #T_cd4f6_row12_col5, #T_cd4f6_row13_col0, #T_cd4f6_row13_col3, #T_cd4f6_row13_col4, #T_cd4f6_row13_col5, #T_cd4f6_row14_col0, #T_cd4f6_row14_col3, #T_cd4f6_row14_col4, #T_cd4f6_row14_col5, #T_cd4f6_row15_col0, #T_cd4f6_row15_col3, #T_cd4f6_row15_col4, #T_cd4f6_row15_col5, #T_cd4f6_row16_col0, #T_cd4f6_row16_col3, #T_cd4f6_row16_col4, #T_cd4f6_row16_col5, #T_cd4f6_row17_col0, #T_cd4f6_row17_col3, #T_cd4f6_row17_col4, #T_cd4f6_row17_col5, #T_cd4f6_row18_col0, #T_cd4f6_row18_col3, #T_cd4f6_row18_col4, #T_cd4f6_row18_col5, #T_cd4f6_row19_col0, #T_cd4f6_row19_col3, #T_cd4f6_row19_col4, #T_cd4f6_row19_col5, #T_cd4f6_row20_col0, #T_cd4f6_row20_col3, #T_cd4f6_row20_col4, #T_cd4f6_row20_col5, #T_cd4f6_row21_col0, #T_cd4f6_row21_col3, #T_cd4f6_row21_col4, #T_cd4f6_row21_col5, #T_cd4f6_row22_col0, #T_cd4f6_row22_col3, #T_cd4f6_row22_col4, #T_cd4f6_row22_col5, #T_cd4f6_row23_col0, #T_cd4f6_row23_col3, #T_cd4f6_row23_col4, #T_cd4f6_row23_col5, #T_cd4f6_row24_col0, #T_cd4f6_row24_col3, #T_cd4f6_row24_col4, #T_cd4f6_row24_col5, #T_cd4f6_row25_col0, #T_cd4f6_row25_col3, #T_cd4f6_row25_col4, #T_cd4f6_row25_col5, #T_cd4f6_row26_col0, #T_cd4f6_row26_col3, #T_cd4f6_row26_col4, #T_cd4f6_row26_col5, #T_cd4f6_row27_col0, #T_cd4f6_row27_col3, #T_cd4f6_row27_col4, #T_cd4f6_row27_col5, #T_cd4f6_row28_col0, #T_cd4f6_row28_col3, #T_cd4f6_row28_col4, #T_cd4f6_row28_col5 {
#   font-family: Segoe UI;
# }
# #T_cd4f6_row0_col1, #T_cd4f6_row1_col1, #T_cd4f6_row2_col1, #T_cd4f6_row3_col1, #T_cd4f6_row3_col2, #T_cd4f6_row4_col1, #T_cd4f6_row4_col2, #T_cd4f6_row5_col1, #T_cd4f6_row6_col1, #T_cd4f6_row6_col2, #T_cd4f6_row7_col1, #T_cd4f6_row7_col2, #T_cd4f6_row8_col1, #T_cd4f6_row9_col1, #T_cd4f6_row9_col2, #T_cd4f6_row10_col1, #T_cd4f6_row10_col2, #T_cd4f6_row11_col1, #T_cd4f6_row11_col2, #T_cd4f6_row12_col1, #T_cd4f6_row12_col2, #T_cd4f6_row13_col1, #T_cd4f6_row13_col2, #T_cd4f6_row14_col1, #T_cd4f6_row15_col1, #T_cd4f6_row16_col1, #T_cd4f6_row16_col2, #T_cd4f6_row17_col1, #T_cd4f6_row17_col2, #T_cd4f6_row18_col1, #T_cd4f6_row19_col1, #T_cd4f6_row20_col1, #T_cd4f6_row20_col2, #T_cd4f6_row21_col1, #T_cd4f6_row21_col2, #T_cd4f6_row22_col1, #T_cd4f6_row22_col2, #T_cd4f6_row23_col1, #T_cd4f6_row23_col2, #T_cd4f6_row24_col1, #T_cd4f6_row24_col2, #T_cd4f6_row25_col1, #T_cd4f6_row25_col2, #T_cd4f6_row26_col1, #T_cd4f6_row26_col2, #T_cd4f6_row27_col1, #T_cd4f6_row27_col2, #T_cd4f6_row28_col1, #T_cd4f6_row28_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cd4f6_row0_col2 {
#   background-color: #fff2eb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cd4f6_row1_col2 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cd4f6_row2_col2, #T_cd4f6_row14_col2, #T_cd4f6_row18_col2, #T_cd4f6_row19_col2 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cd4f6_row5_col2 {
#   background-color: #ffeee7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cd4f6_row8_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cd4f6_row15_col2 {
#   background-color: #f34935;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_cd4f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd4f6_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_cd4f6_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_cd4f6_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_cd4f6_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_cd4f6_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_cd4f6_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd4f6_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_cd4f6_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_cd4f6_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_cd4f6_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_cd4f6_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_cd4f6_row0_col4" class="data row0 col4" >60.000000</td>
#       <td id="T_cd4f6_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_cd4f6_level0_row1" class="row_heading level0 row1" >DailyAchievement</th>
#       <td id="T_cd4f6_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_cd4f6_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_cd4f6_row1_col2" class="data row1 col2" >60</td>
#       <td id="T_cd4f6_row1_col3" class="data row1 col3" >102.000000</td>
#       <td id="T_cd4f6_row1_col4" class="data row1 col4" >1499.000000</td>
#       <td id="T_cd4f6_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_cd4f6_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_cd4f6_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_cd4f6_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_cd4f6_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_cd4f6_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_cd4f6_row2_col4" class="data row2 col4" >29.000000</td>
#       <td id="T_cd4f6_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_cd4f6_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_cd4f6_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_cd4f6_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_cd4f6_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_cd4f6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_cd4f6_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_cd4f6_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_cd4f6_level0_row4" class="row_heading level0 row4" >EnvironmentSatisfaction</th>
#       <td id="T_cd4f6_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_cd4f6_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_cd4f6_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_cd4f6_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_cd4f6_row4_col4" class="data row4 col4" >4.000000</td>
#       <td id="T_cd4f6_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_cd4f6_level0_row5" class="row_heading level0 row5" >HourlyAchievement</th>
#       <td id="T_cd4f6_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_cd4f6_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_cd4f6_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_cd4f6_row5_col3" class="data row5 col3" >30.000000</td>
#       <td id="T_cd4f6_row5_col4" class="data row5 col4" >100.000000</td>
#       <td id="T_cd4f6_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_cd4f6_level0_r
# Total Number of Scatter Plots = 210
# All Plots are saved in .\AutoViz_Plots\Attrition
# Time to run AutoViz = 64 seconds
